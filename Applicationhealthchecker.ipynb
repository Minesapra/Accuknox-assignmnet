# %%
import requests

# %%
pip install psutil requests

# %%
def check_application_health(url):
    """Check the application health by making a GET request."""
    try:
        response = requests.get(url)
        if response.status_code == 200:
            print(f"Application is up. Status code: {response.status_code}")
        else:
            print(f"Application is down. Status code: {response.status_code}")
    except requests.exceptions.RequestException as e:
        print(f"Application is down. Error: {e}")

# %%
url = input("Enter the application URL to check: ")
check_application_health(url)
# Out:
# Enter the application URL to check: http://www.google.com
# Application is up. Status code: 200
